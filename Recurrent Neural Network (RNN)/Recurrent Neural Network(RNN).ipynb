# %% [markdown]
# # Recurrent Neural Network (RNN)

# %% [markdown]
# ## Loading and Preprocessing Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_tr = pd.read_csv('Stock_Price_Train.csv')

# %%
df_tr.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
train = df_tr.loc[:,["Open"]].values
train
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train_scaled = scaler.fit_transform(train)
train_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
plt.plot(train_scaled)
plt.show()

# %%
# 50 timesteps and 1 output
x_train = []
y_train = []
timesteps = 50
for i in range(timesteps,1258):
    x_train.append(train_scaled[i-timesteps:i,0])
    y_train.append(train_scaled[i,0])
x_train , y_train = np.array(x_train), np.array(y_train)

# %%
x_train
# Out:
# array([[0.08581368, 0.09701243, 0.09433366, ..., 0.03675869, 0.04486941,
#         0.05065481],
#        [0.09701243, 0.09433366, 0.09156187, ..., 0.04486941, 0.05065481,
#         0.05214302],
#        [0.09433366, 0.09156187, 0.07984225, ..., 0.05065481, 0.05214302,
#         0.05612397],
#        ...,
#        [0.9313937 , 0.94636878, 0.96569685, ..., 0.95475854, 0.95204256,
#         0.95163331],
#        [0.94636878, 0.96569685, 0.97510976, ..., 0.95204256, 0.95163331,
#         0.95725128],
#        [0.96569685, 0.97510976, 0.95966962, ..., 0.95163331, 0.95725128,
#         0.93796041]])

# %%
# Reshaping
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.03675869],
#         [0.04486941],
#         [0.05065481]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.04486941],
#         [0.05065481],
#         [0.05214302]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.05065481],
#         [0.05214302],
#         [0.05612397]],
#
#        ...,
#
#        [[0.9313937 ],
#         [0.94636878],
#         [0.96569685],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.94636878],
#         [0.96569685],
#         [0.97510976],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.96569685],
#         [0.97510976],
#         [0.95966962],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %%
y_train
# Out:
# array([0.05214302, 0.05612397, 0.05818885, ..., 0.95725128, 0.93796041,
#        0.93688146])

# %% [markdown]
# ## Create RNN Model

# %%
#pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# %%
regressor = Sequential()

regressor.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second RNN layer and some Dropout regularisation
regressor.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third RNN layer and some Dropout regularisation
regressor.add(SimpleRNN(units = 50,activation='tanh', return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth RNN layer and some Dropout regularisation
regressor.add(SimpleRNN(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(x_train, y_train, epochs = 250, batch_size = 32)
# Out:
# Epoch 1/250
# 38/38 [==============================] - 2s 15ms/step - loss: 0.3469
# Epoch 2/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.2244
# Epoch 3/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.1571
# Epoch 4/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.1277
# Epoch 5/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0972
# Epoch 6/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0722
# Epoch 7/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0634
# Epoch 8/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0545
# Epoch 9/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0478
# Epoch 10/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0448
# Epoch 11/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0386
# Epoch 12/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0351
# Epoch 13/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0305
# Epoch 14/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0279
# Epoch 15/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0248
# Epoch 16/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0236
# Epoch 17/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0195
# Epoch 18/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0187
# Epoch 19/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0189
# Epoch 20/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0175
# Epoch 21/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0152
# Epoch 22/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0136
# Epoch 23/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0131
# Epoch 24/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0124
# Epoch 25/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0116
# Epoch 26/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0114
# Epoch 27/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0102
# Epoch 28/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0100
# Epoch 29/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0091
# Epoch 30/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0093
# Epoch 31/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0090
# Epoch 32/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0081
# Epoch 33/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0078
# Epoch 34/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0075
# Epoch 35/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0073
# Epoch 36/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0068
# Epoch 37/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0063
# Epoch 38/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0069
# Epoch 39/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0068
# Epoch 40/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0056
# Epoch 41/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0060
# Epoch 42/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0061
# Epoch 43/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0057
# Epoch 44/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0052
# Epoch 45/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0052
# Epoch 46/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0049
# Epoch 47/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0050
# Epoch 48/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 49/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 50/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0046
# Epoch 51/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0043
# Epoch 52/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 53/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0040
# Epoch 54/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 55/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0037
# Epoch 56/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0038
# Epoch 57/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0036
# Epoch 58/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0035
# Epoch 59/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0034
# Epoch 60/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0035
# Epoch 61/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0031
# Epoch 62/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0032
# Epoch 63/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0034
# Epoch 64/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0030
# Epoch 65/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0029
# Epoch 66/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0032
# Epoch 67/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 68/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 69/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 70/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0029
# Epoch 71/250
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0031
# Epoch 72/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0027
# Epoch 73/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 74/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0028
# Epoch 75/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0026
# Epoch 76/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0027
# Epoch 77/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0025
# Epoch 78/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0025
# Epoch 79/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0025
# Epoch 80/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 81/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0028
# Epoch 82/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0022
# Epoch 83/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0023
# Epoch 84/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0023
# Epoch 85/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 86/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 87/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 88/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 89/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 90/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0026
# Epoch 91/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 92/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 93/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 94/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 95/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 96/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0021
# Epoch 97/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0021
# Epoch 98/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0021
# Epoch 99/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 100/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 101/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 102/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 103/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 104/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0023
# Epoch 105/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0020
# Epoch 106/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 107/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0017
# Epoch 108/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 109/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0017
# Epoch 110/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 111/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 112/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0019
# Epoch 113/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 114/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0018
# Epoch 115/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 116/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 117/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 118/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 119/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0015
# Epoch 120/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 121/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 122/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 123/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 124/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 125/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 126/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 127/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 128/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 129/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 130/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0017
# Epoch 131/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 132/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0016
# Epoch 133/250
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0021
# Epoch 134/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0020
# Epoch 135/250
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0017
# Epoch 136/250
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0017
# Epoch 137/250
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0014
# Epoch 138/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0016
# Epoch 139/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0016
# Epoch 140/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 141/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 142/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 143/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0016
# Epoch 144/250
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0015
# Epoch 145/250
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0016
# Epoch 146/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0015
# Epoch 147/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 148/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 149/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 150/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 151/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 152/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 153/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0015
# Epoch 154/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 155/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 156/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 157/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 158/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 159/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 160/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0012
# Epoch 161/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 162/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 163/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 164/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 165/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 166/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 167/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 168/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 169/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 170/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 171/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 172/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 173/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 174/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 175/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 176/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 177/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 178/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 179/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 180/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 181/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 182/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 183/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 184/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 185/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 186/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 187/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 188/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 189/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 190/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 191/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 192/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 193/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 194/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 195/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 196/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 197/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 198/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 199/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 200/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 201/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 202/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 203/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 204/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 205/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 206/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 207/250
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0012
# Epoch 208/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 209/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 210/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 211/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 212/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 213/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 214/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 215/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0012
# Epoch 216/250
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0014
# Epoch 217/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 218/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 219/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 220/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 221/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 222/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 223/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 224/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 225/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 226/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 227/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 228/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 229/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 230/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 231/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 232/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 233/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 234/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 235/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 236/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0010
# Epoch 237/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 238/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0014
# Epoch 239/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 240/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 241/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 242/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 243/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 244/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 245/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 246/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 247/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 248/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0013
# Epoch 249/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 250/250
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0011

# %% [markdown]
# ## Predictions and Visualising RNN Model

# %%
dataset_test = pd.read_csv('Stock_Price_Test.csv')
dataset_test.head()
# Out:
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %%
real_stock = dataset_test.loc[:,["Open"]].values
real_stock
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
dataset_total = pd.concat((df_tr["Open"],dataset_test["Open"]),axis = 0)
inputs = dataset_total[len(dataset_total)-len(dataset_test)-timesteps:].values.reshape(-1,1)
inputs = scaler.transform(inputs)
inputs
# Out:
# array([[0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146],
#        [0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %%
X_test = []
for i in range(timesteps, 70):
    X_test.append(inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

# Visualising the results
plt.plot(real_stock, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 201ms/step
